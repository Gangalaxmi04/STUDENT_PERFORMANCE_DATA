# %% [raw]
# Problem Statement:
# The dataset provided contains information about 2392 students, including demographic information, extracurricular activities, academic performance, and other related factors. The objective is to analyze the data to gain insights into how various factors impact students' GPA

# %% [raw]
# Data Columns and Their Meanings
# StudentID: Unique identifier for each student.
# Age: Age of the student.
# Gender: Gender of the student (possibly encoded as integers).
# Ethnicity: Ethnicity of the student (possibly encoded as integers).
#     0: White
#     1: Black or African American
#     2: Hispanic or Latino
#     3: Asian
#     4: Native American or Alaska Native
#     5: Native Hawaiian or Other Pacific Islander
#     6: Other
# ParentalEducation: Education level of the student's parents (possibly encoded as integers).
# StudyTimeWeekly: Number of hours spent studying per week.
# Absences: Number of school absences.
# Tutoring: Whether the student receives tutoring (possibly encoded as integers).
#        0 indicates that the student did not receive tutoring.
#        1 indicates that the student received tutoring.
# ParentalSupport: Level of parental support (possibly encoded as integers).
# Extracurricular: Participation in extracurricular activities (possibly encoded as integers).
#        0 indicates that the student did not in extracurricular.
#        1 indicates that the student in extracurricular.
# Sports: Participation in sports activities (possibly encoded as integers).
#        0 indicates that the student did not participate in sports.
#        1 indicates that the student in sports.
# Music: Participation in music activities (possibly encoded as integers).
#        0 indicates that the student did not listens music.
#        1 indicates that the student listens music.
# Volunteering: Participation in volunteering activities (possibly encoded as integers).
# GPA: Grade Point Average of the student.
# GradeClass: The class/grade level of the student.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv(r"file:///C:\Users\Hp\Downloads\Student_performance_data%20_.csv")

# %%
df.head()
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
# 2       1003   15       0          2                  3         4.210570
# 3       1004   17       1          0                  3        10.028829
# 4       1005   17       1          0                  2         4.672495
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# 1         0         0                1                0       0      0
# 2        26         0                2                0       0      0
# 3        14         0                3                1       0      0
# 4        17         1                3                0       0      0
#
#    Volunteering       GPA  GradeClass
# 0             0  2.929196         2.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2392 entries, 0 to 2391
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   StudentID          2392 non-null   int64
#  1   Age                2392 non-null   int64
#  2   Gender             2392 non-null   int64
#  3   Ethnicity          2392 non-null   int64
#  4   ParentalEducation  2392 non-null   int64
#  5   StudyTimeWeekly    2392 non-null   float64
#  6   Absences           2392 non-null   int64
#  7   Tutoring           2392 non-null   int64
#  8   ParentalSupport    2392 non-null   int64
#  9   Extracurricular    2392 non-null   int64
#  10  Sports             2392 non-null   int64
#  11  Music              2392 non-null   int64
#  12  Volunteering       2392 non-null   int64
#  13  GPA                2392 non-null   float64
#  14  GradeClass         2392 non-null   float64
# dtypes: float64(3), int64(12)
# memory usage: 280.4 KB

# %%
df.columns
# Out:
# Index(['StudentID', 'Age', 'Gender', 'Ethnicity', 'ParentalEducation',
#        'StudyTimeWeekly', 'Absences', 'Tutoring', 'ParentalSupport',
#        'Extracurricular', 'Sports', 'Music', 'Volunteering', 'GPA',
#        'GradeClass'],
#       dtype='object')

# %%
plt.hist(df['GPA'], bins=10, edgecolor='black')
plt.xlabel('GPA')
plt.ylabel('Number of Students')
plt.title('Distribution of GPA')
plt.show()

# %%
sns.boxplot(x='Gender', y='GPA', data=df)
plt.xlabel('Gender')
plt.ylabel('GPA')
plt.title('GPA Distribution by Gender')
plt.show()

# %%
plt.scatter(df['StudyTimeWeekly'], df['GPA'], alpha=0.5)
plt.xlabel('Study Time Weekly (hours)')
plt.ylabel('GPA')
plt.title('Study Time vs. GPA')
plt.show()

# %%
#droping irrelvant features
df=df.drop(columns=['StudentID', 'Age', 'Gender','Ethnicity','Music'])

# %%
df.head()
# Out:
#    ParentalEducation  StudyTimeWeekly  Absences  Tutoring  ParentalSupport  \
# 0                  2        19.833723         7         1                2
# 1                  1        15.408756         0         0                1
# 2                  3         4.210570        26         0                2
# 3                  3        10.028829        14         0                3
# 4                  2         4.672495        17         1                3
#
#    Extracurricular  Sports  Volunteering       GPA  GradeClass
# 0                0       0             0  2.929196         2.0
# 1                0       0             0  3.042915         1.0
# 2                0       0             0  0.112602         4.0
# 3                1       0             0  2.054218         3.0
# 4                0       0             0  1.288061         4.0

# %%
df.isnull().sum()
# Out:
# ParentalEducation    0
# StudyTimeWeekly      0
# Absences             0
# Tutoring             0
# ParentalSupport      0
# Extracurricular      0
# Sports               0
# Volunteering         0
# GPA                  0
# GradeClass           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.head()
# Out:
#    ParentalEducation  StudyTimeWeekly  Absences  Tutoring  ParentalSupport  \
# 0                  2        19.833723         7         1                2
# 1                  1        15.408756         0         0                1
# 2                  3         4.210570        26         0                2
# 3                  3        10.028829        14         0                3
# 4                  2         4.672495        17         1                3
#
#    Extracurricular  Sports  Volunteering       GPA  GradeClass
# 0                0       0             0  2.929196         2.0
# 1                0       0             0  3.042915         1.0
# 2                0       0             0  0.112602         4.0
# 3                1       0             0  2.054218         3.0
# 4                0       0             0  1.288061         4.0

# %%
x = df.drop(columns=['GPA'])

# %%
y=df[['GPA']]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
x_train.corr()
# Out:
#                    ParentalEducation  StudyTimeWeekly  Absences  Tutoring  \
# ParentalEducation           1.000000        -0.025295  0.027732 -0.033441
# StudyTimeWeekly            -0.025295         1.000000 -0.000609  0.040517
# Absences                    0.027732        -0.000609  1.000000 -0.004705
# Tutoring                   -0.033441         0.040517 -0.004705  1.000000
# ParentalSupport            -0.013868         0.044202  0.016651  0.009058
# Extracurricular            -0.002064        -0.035274  0.009363  0.010930
# Sports                     -0.014395         0.026725  0.033370  0.019773
# Volunteering                0.015194        -0.011130 -0.013961 -0.049305
# GradeClass                  0.041066        -0.138590  0.726451 -0.112615
#
#                    ParentalSupport  Extracurricular    Sports  Volunteering  \
# ParentalEducation        -0.013868        -0.002064 -0.014395      0.015194
# ...

# %%
def correlation(dataset,threshold):
    col_corr=set()
    corr_matrix=x_train.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i,j])>threshold:
                colname=corr_matrix.columns[i]
                col_corr.add(colname)
    return col_corr

# %%
corr_features=correlation(x_train,0.75)

# %%
corr_features
# Out:
# set()

# %%
#no multicolinearity

# %%
#lets build model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

lr = LinearRegression()
lr.fit(x_train, y_train)
y_pred_lr = lr.predict(x_test)
mse_lr = mean_squared_error(y_test, y_pred_lr)
r2_lr = r2_score(y_test, y_pred_lr)
print("Linear Regression MSE:", mse_lr)
print("Linear Regression R²:", r2_lr)
# Out:
# Linear Regression MSE: 0.037752808292322124
# Linear Regression R²: 0.9536427015756929
